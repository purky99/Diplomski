# %% [markdown]
# <a href="https://colab.research.google.com/github/purky99/Diplomski/blob/main/Untitled13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow==2.10.0
# !pip install keras==2.10.0
# !pip install segmentation-models

# %%
from google.colab import drive
drive.mount('/content/drive')
# !unzip /content/drive/My\ Drive/data.zip -d /content/
dataset_path = '/content/data'

# %%
# po folderima bez redundancije
import os
import cv2
import numpy as np
import segmentation_models as sm
import random
import glob
import keras
import re
import keras.backend as K
import matplotlib.pyplot as plt
from segmentation_models import Unet
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.callbacks import ReduceLROnPlateau


BACKBONE = 'resnet34'
preprocess_input = sm.get_preprocessing(BACKBONE)
keras.backend.set_image_data_format('channels_last')

data_dir = '/content/data'
image_dir = os.path.join(data_dir, 'images')
input_shape = (480, 480, 3)

# specify the list of mask filenames you want to extract
mask_filenames = []
for i in range(6000):
    filename = 'LargeAmmoCanHandles.001_frame_{:04d}.png'.format(i)
    mask_filenames.append(filename)

# Get a list of all image filenames in the image_dir
all_image_filenames = os.listdir(image_dir)

# randomly select 100 image filenames
selected_image_filenames = random.sample(all_image_filenames, 150)

# create a list of mask filenames that correspond to the selected image filenames
selected_mask_paths = []
filtered_image_filenames = []
for image_filename in selected_image_filenames:
    image_number = os.path.splitext(image_filename)[0]
    image_number = "".join(re.findall(r'\d+', image_number))
    mask_path = os.path.join(data_dir, 'masks', image_number)
    mask_found = False
    for mask_name in mask_filenames:
        current_mask_path = os.path.join(mask_path, mask_name)
        if os.path.exists(current_mask_path):
            mask_found = True
            selected_mask_paths.append(current_mask_path)
            break
    if mask_found:
        filtered_image_filenames.append(image_filename)
    else:
        print("No mask file found for selected image: {}. Skipping image...".format(image_filename))
        
# create lists of image and mask paths for the selected images
selected_image_paths = [os.path.join(image_dir, f) for f in filtered_image_filenames]

print(selected_image_paths)
print(selected_mask_paths)

# split the selected image and mask paths into train and validation sets
train_paths, val_paths, train_mask_paths, val_mask_paths = train_test_split(selected_image_paths, selected_mask_paths, test_size=0.2, random_state=42)

# load the train images and masks
x_train = []
y_train = []
# load the validation images and masks
x_val = []
y_val = []

all_paths = train_paths + val_paths
all_mask_paths = train_mask_paths + val_mask_paths

x_data = []
y_data = []
for img_path, mask_path in zip(all_paths, all_mask_paths):
    # load the image
    img = cv2.imread(img_path, cv2.IMREAD_COLOR)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = cv2.resize(img, input_shape[:2], interpolation=cv2.INTER_LINEAR)

    # # preprocess the image
    img = preprocess_input(img)
    img = img / 255.0

    # load the mask
    mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
    mask = cv2.resize(mask, input_shape[:2], interpolation=cv2.INTER_NEAREST)

    # threshold the mask to convert to binary mask
    _, mask = cv2.threshold(mask, 127, 255, cv2.THRESH_BINARY)

    # apply morphological opening operation to remove small noise in the mask
    kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (5, 5))
    mask = cv2.morphologyEx(mask, cv2.MORPH_OPEN, kernel)

    # add to the lists
    x_data.append(img)
    y_data.append(mask)

# Separate the combined lists into train and validation lists
x_train = x_data[:len(train_paths)]
y_train = y_data[:len(train_mask_paths)]
x_val = x_data[len(train_paths):]
y_val = y_data[len(train_mask_paths):]

# convert to numpy arrays
x_train = np.array(x_train)
y_train = np.array(y_train)

# convert to numpy arrays
x_val = np.array(x_val)
y_val = np.array(y_val)

def load_data():
    # preprocess input
    x_train_pre = (x_train)
    x_val_pre = (x_val)

    # resize masks to fixed size
    mask_size = (480, 480) # set a fixed size for the masks
    y_train_resized = [cv2.resize(mask, mask_size, interpolation=cv2.INTER_NEAREST) for mask in y_train]
    y_val_resized = [cv2.resize(mask, mask_size, interpolation=cv2.INTER_NEAREST) for mask in y_val]

    # convert the lists to numpy arrays
    y_train_resized = np.array(y_train_resized)
    y_val_resized = np.array(y_val_resized)

    # normalize masks
    y_train_normalized = y_train_resized / 255.0
    y_val_normalized = y_val_resized / 255.0

    
    # expand dimensions for masks
    y_train_expanded = np.expand_dims(y_train_normalized, axis=-1)
    y_val_expanded = np.expand_dims(y_val_normalized, axis=-1)

    return x_train_pre, y_train_expanded, x_val_pre, y_val_expanded

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=10, verbose=1, mode='auto', min_lr=0.00001)

# define model
model = sm.Unet(BACKBONE, classes=1, activation='sigmoid', encoder_weights='imagenet')
model.compile(
    'Adam',
    loss=sm.losses.bce_jaccard_loss,
    metrics=[sm.metrics.iou_score],
)

# load your data
x_train, y_train, x_val, y_val = load_data()

early_stopping_callback = EarlyStopping(monitor='val_loss', patience=20, verbose=1)

checkpoint_callback = ModelCheckpoint(
    filepath='model_weights_ep{epoch:02d}.h5',
    monitor='val_loss',
    save_weights_only=True,
    save_best_only=False,
    verbose=1
)

history = model.fit(x=x_train, y=y_train, batch_size=16, epochs=50, validation_data=(x_val, y_val), callbacks=[reduce_lr, checkpoint_callback, early_stopping_callback])

# # fit the model
# history = model.fit(
#    x=x_train,
#    y=y_train,
#    batch_size=16,
#    epochs=100,  # Increase the number of epochs
#    validation_data=(x_val, y_val),
#    callbacks=[checkpoint_callback, early_stopping_callback]
# )
# Out:
# Segmentation Models: using `keras` framework.
# No mask file found for selected image: 1182.jpg. Skipping image...
# No mask file found for selected image: 5350.jpg. Skipping image...
# No mask file found for selected image: 1045.jpg. Skipping image...
# No mask file found for selected image: 1589.jpg. Skipping image...
# No mask file found for selected image: 242.jpg. Skipping image...
# No mask file found for selected image: 968.jpg. Skipping image...
# No mask file found for selected image: 3962.jpg. Skipping image...
# No mask file found for selected image: 2360.jpg. Skipping image...
# No mask file found for selected image: 2916.jpg. Skipping image...
# No mask file found for selected image: 1414.jpg. Skipping image...
# No mask file found for selected image: 5236.jpg. Skipping image...
# No mask file found for selected image: 2920.jpg. Skipping image...
# No mask file found for selected image: 2463.jpg. Skipping image...
# No mask file found for selected image: 3456.jpg. Skipping image...
# No mask file found for selected image: 1366.jpg. Skipping image...
# No mask file found for selected image: 4935.jpg. Skipping image...
# No mask file found for selected image: 5689.jpg. Skipping image...
# No mask file found for selected image: 2265.jpg. Skipping image...
# No mask file found for selected image: 1402.jpg. Skipping image...
# No mask file found for selected image: 872.jpg. Skipping image...
# No mask file found for selected image: 325.jpg. Skipping image...
# No mask file found for selected image: 1165.jpg. Skipping image...
# No mask file found for selected image: 4671.jpg. Skipping image...
# No mask file found for selected image: 2631.jpg. Skipping image...
# No mask file found for selected image: 297.jpg. Skipping image...
# No mask file found for selected image: 772.jpg. Skipping image...
# No mask file found for selected image: 1759.jpg. Skipping image...
# No mask file found for selected image: 2908.jpg. Skipping image...
# No mask file found for selected image: 5162.jpg. Skipping image...
# No mask file found for selected image: 4994.jpg. Skipping image...
# No mask file found for selected image: 3450.jpg. Skipping image...
# No mask file found for selected image: 5667.jpg. Skipping image...
# No mask file found for selected image: 2690.jpg. Skipping image...
# No mask file found for selected image: 2654.jpg. Skipping image...
# No mask file found for selected image: 1974.jpg. Skipping image...
# No mask file found for selected image: 3975.jpg. Skipping image...
png', '/content/data/masks/4033/LargeAmmoCanHandles.001_frame_3686.png', '/content/data/masks/5130/LargeAmmoCanHandles.001_frame_2229.png', '/content/data/masks/3825/LargeAmmoCanHandles.001_frame_1312.png', '/content/data/masks/2174/LargeAmmoCanHandles.001_frame_0647.png', '/content/data/masks/4457/LargeAmmoCanHandles.001_frame_2351.png', '/content/data/masks/5138/LargeAmmoCanHandles.001_frame_1985.png', '/content/data/masks/3357/LargeAmmoCanHandles.001_frame_2421.png', '/content/data/masks/5718/LargeAmmoCanHandles.001_frame_0512.png', '/content/data/masks/1523/LargeAmmoCanHandles.001_frame_0358.png', '/content/data/masks/3005/LargeAmmoCanHandles.001_frame_1169.png', '/content/data/masks/5603/LargeAmmoCanHandles.001_frame_2588.png', '/content/data/masks/1865/LargeAmmoCanHandles.001_frame_1835.png', '/content/data/masks/652/LargeAmmoCanHandles.001_frame_1986.png', '/content/data/masks/3808/LargeAmmoCanHandles.001_frame_2816.png', '/content/data/masks/5421/LargeAmmoCanHandles.001_frame_2343.png', '/content/data/masks/5486/LargeAmmoCanHandles.001_frame_0002.png', '/content/data/masks/4068/LargeAmmoCanHandles.001_frame_1597.png', '/content/data/masks/4739/LargeAmmoCanHandles.001_frame_2408.png', '/content/data/masks/3841/LargeAmmoCanHandles.001_frame_0820.png', '/content/data/masks/2052/LargeAmmoCanHandles.001_frame_1893.png', '/content/data/masks/2996/LargeAmmoCanHandles.001_frame_3499.png', '/content/data/masks/2784/LargeAmmoCanHandles.001_frame_0083.png', '/content/data/masks/3672/LargeAmmoCanHandles.001_frame_3014.png', '/content/data/masks/3102/LargeAmmoCanHandles.001_frame_2917.png', '/content/data/masks/2940/LargeAmmoCanHandles.001_frame_2736.png', '/content/data/masks/3170/LargeAmmoCanHandles.001_frame_1749.png', '/content/data/masks/4254/LargeAmmoCanHandles.001_frame_0731.png', '/content/data/masks/3508/LargeAmmoCanHandles.001_frame_1972.png', '/content/data/masks/5586/LargeAmmoCanHandles.001_frame_0562.png', '/content/data/masks/1492/LargeAmmoCanHandles.001_frame_2418.png', '/content/data/masks/3832/LargeAmmoCanHandles.001_frame_1010.png', '/content/data/masks/148/LargeAmmoCanHandles.001_frame ...
# Downloading data from https://github.com/qubvel/classification_models/releases/download/0.0.1/resnet34_imagenet_1000_no_top.h5
# 85521592/85521592 [==============================] - 1s 0us/step
# Epoch 1/50
# 4/4 [==============================] - ETA: 0s - loss: 1.3923 - iou_score: 0.0056
# Epoch 1: saving model to model_weights_ep01.h5
# 4/4 [==============================] - 380s 90s/step - loss: 1.3923 - iou_score: 0.0056 - val_loss: 1.0850 - val_iou_score: 0.0026 - lr: 0.0010
# Epoch 2/50
# 4/4 [==============================] - ETA: 0s - loss: 1.2242 - iou_score: 0.0074
# Epoch 2: saving model to model_weights_ep02.h5
# 4/4 [==============================] - 360s 89s/step - loss: 1.2242 - iou_score: 0.0074 - val_loss: 1.0521 - val_iou_score: 0.0013 - lr: 0.0010
# Epoch 3/50
# 4/4 [==============================] - ETA: 0s - loss: 1.1411 - iou_score: 0.0139
# Epoch 3: saving model to model_weights_ep03.h5
# 4/4 [==============================] - 354s 86s/step - loss: 1.1411 - iou_score: 0.0139 - val_loss: 1.0683 - val_iou_score: 8.2721e-04 - lr: 0.0010
# Epoch 4/50
# 4/4 [==============================] - ETA: 0s - loss: 1.0982 - iou_score: 0.0211
# Epoch 4: saving model to model_weights_ep04.h5
# 4/4 [==============================] - 361s 88s/step - loss: 1.0982 - iou_score: 0.0211 - val_loss: 1.1335 - val_iou_score: 4.3866e-04 - lr: 0.0010
# Epoch 5/50
# 4/4 [==============================] - ETA: 0s - loss: 1.0532 - iou_score: 0.0377
# Epoch 5: saving model to model_weights_ep05.h5
# 4/4 [==============================] - 363s 89s/step - loss: 1.0532 - iou_score: 0.0377 - val_loss: 1.6107 - val_iou_score: 8.1549e-05 - lr: 0.0010
# Epoch 6/50
# 4/4 [==============================] - ETA: 0s - loss: 1.0238 - iou_score: 0.0505
# Epoch 6: saving model to model_weights_ep06.h5
# 4/4 [==============================] - 357s 88s/step - loss: 1.0238 - iou_score: 0.0505 - val_loss: 15.5908 - val_iou_score: 5.0755e-10 - lr: 0.0010
# Epoch 7/50
# 4/4 [==============================] - ETA: 0s - loss: 0.9886 - iou_score: 0.0711
# Epoch 7: saving model to model_weights_ep07.h5
# 4/4 [==============================] - 352s 87s/step - loss: 0.9886 - iou_score: 0.0711 - val_loss: 64.9169 - val_iou_score: 5.0809e-10 - lr: 0.0010
# Epoch 8/50
# 4/4 [==============================] - ETA: 0s - loss: 0.9617 - iou_score: 0.0853
# Epoch 8: saving model to model_weights_ep08.h5
# 4/4 [==============================] - 354s 86s/step - loss: 0.9617 - iou_score: 0.0853 - val_loss: 3.2217 - val_iou_score: 5.5354e-10 - lr: 0.0010
# Epoch 9/50
# 4/4 [==============================] - ETA: 0s - loss: 0.9330 - iou_score: 0.1080
# Epoch 9: saving model to model_weights_ep09.h5
# 4/4 [==============================] - 360s 88s/step - loss: 0.9330 - iou_score: 0.1080 - val_loss: 1.2253 - val_iou_score: 2.1437e-04 - lr: 0.0010
# Epoch 10/50
# 4/4 [==============================] - ETA: 0s - loss: 0.9034 - iou_score: 0.1268
# Epoch 10: saving model to model_weights_ep10.h5
# 4/4 [==============================] - 356s 87s/step - loss: 0.9034 - iou_score: 0.1268 - val_loss: 1.5953 - val_iou_score: 3.3480e-04 - lr: 0.0010
# Epoch 11/50
# 4/4 [==============================] - ETA: 0s - loss: 0.8649 - iou_score: 0.1695
# Epoch 11: saving model to model_weights_ep11.h5
# 4/4 [==============================] - 357s 88s/step - loss: 0.8649 - iou_score: 0.1695 - val_loss: 1.7237 - val_iou_score: 1.5514e-05 - lr: 0.0010
# Epoch 12/50
# 4/4 [==============================] - ETA: 0s - loss: 0.8302 - iou_score: 0.1908
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 12: saving model to model_weights_ep12.h5
# 4/4 [==============================] - 355s 88s/step - loss: 0.8302 - iou_score: 0.1908 - val_loss: 1.3894 - val_iou_score: 1.6646e-04 - lr: 0.0010
# Epoch 13/50
# 4/4 [==============================] - ETA: 0s - loss: 0.7932 - iou_score: 0.2133
# Epoch 13: saving model to model_weights_ep13.h5
# 4/4 [==============================] - 352s 86s/step - loss: 0.7932 - iou_score: 0.2133 - val_loss: 1.5910 - val_iou_score: 0.0031 - lr: 1.0000e-04
# Epoch 14/50
# 4/4 [==============================] - ETA: 0s - loss: 0.7752 - iou_score: 0.2444
# Epoch 14: saving model to model_weights_ep14.h5
# 4/4 [==============================] - 357s 87s/step - loss: 0.7752 - iou_score: 0.2444 - val_loss: 3.7039 - val_iou_score: 0.0058 - lr: 1.0000e-04
# Epoch 15/50
# 4/4 [==============================] - ETA: 0s - loss: 0.7769 - iou_score: 0.2313
# Epoch 15: saving model to model_weights_ep15.h5
# 4/4 [==============================] - 355s 87s/step - loss: 0.7769 - iou_score: 0.2313 - val_loss: 2.4760 - val_iou_score: 0.0060 - lr: 1.0000e-04
# Epoch 16/50
# 4/4 [==============================] - ETA: 0s - loss: 0.7675 - iou_score: 0.2527
# Epoch 16: saving model to model_weights_ep16.h5
# 4/4 [==============================] - 354s 87s/step - loss: 0.7675 - iou_score: 0.2527 - val_loss: 1.5078 - val_iou_score: 0.0054 - lr: 1.0000e-04
# Epoch 17/50
# 4/4 [==============================] - ETA: 0s - loss: 0.7538 - iou_score: 0.2623
# Epoch 17: saving model to model_weights_ep17.h5
# 4/4 [==============================] - 357s 87s/step - loss: 0.7538 - iou_score: 0.2623 - val_loss: 1.3442 - val_iou_score: 0.0061 - lr: 1.0000e-04
# Epoch 18/50
# 4/4 [==============================] - ETA: 0s - loss: 0.7465 - iou_score: 0.2689
# Epoch 18: saving model to model_weights_ep18.h5
# 4/4 [==============================] - 361s 88s/step - loss: 0.7465 - iou_score: 0.2689 - val_loss: 1.1625 - val_iou_score: 0.0041 - lr: 1.0000e-04
# Epoch 19/50
# 4/4 [==============================] - ETA: 0s - loss: 0.7386 - iou_score: 0.2736
# Epoch 19: saving model to model_weights_ep19.h5
# 4/4 [==============================] - 351s 86s/step - loss: 0.7386 - iou_score: 0.2736 - val_loss: 1.2181 - val_iou_score: 0.0037 - lr: 1.0000e-04
# Epoch 20/50
# 4/4 [==============================] - ETA: 0s - loss: 0.7252 - iou_score: 0.2814
# Epoch 20: saving model to model_weights_ep20.h5
# 4/4 [==============================] - 355s 86s/step - loss: 0.7252 - iou_score: 0.2814 - val_loss: 1.3951 - val_iou_score: 0.0099 - lr: 1.0000e-04
# Epoch 21/50
# 4/4 [==============================] - ETA: 0s - loss: 0.7174 - iou_score: 0.2884
# Epoch 21: saving model to model_weights_ep21.h5
# 4/4 [==============================] - 365s 87s/step - loss: 0.7174 - iou_score: 0.2884 - val_loss: 1.4752 - val_iou_score: 0.0090 - lr: 1.0000e-04
# Epoch 22/50
# 4/4 [==============================] - ETA: 0s - loss: 0.7072 - iou_score: 0.3057
# Epoch 22: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 22: saving model to model_weights_ep22.h5
# 4/4 [==============================] - 358s 87s/step - loss: 0.7072 - iou_score: 0.3057 - val_loss: 1.7349 - val_iou_score: 0.0075 - lr: 1.0000e-04
# Epoch 22: early stopping

# %%
import matplotlib.pyplot as plt

# Plot training & validation IoU scores
plt.figure(figsize=(12, 6))
plt.plot(history.history['iou_score'], label='Training IoU Score')
plt.plot(history.history['val_iou_score'], label='Validation IoU Score')
plt.title('Model IoU Score')
plt.ylabel('IoU Score')
plt.xlabel('Epoch')
plt.legend(loc='upper left')
plt.show()

# Plot training & validation loss values
plt.figure(figsize=(12, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='upper right')
plt.show()

# %%
import matplotlib.pyplot as plt
import cv2

def visualize_image_and_mask(image_path, mask_path):
    image = cv2.imread(image_path)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    
    mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
    
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))
    ax1.imshow(image)
    ax1.set_title("Image")
    
    ax2.imshow(mask, cmap='gray')
    ax2.set_title("Mask")
    
    plt.show()

image_paths = [selected_image_paths]  # Your list of image paths
mask_paths = [selected_mask_paths]  # Your list of mask paths

# Visualize the first 5 image-mask pairs
for i in range(5):
    visualize_image_and_mask(image_paths[i], mask_paths[i])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-e20601715980> in <cell line: 23>()
#      22 # Visualize the first 5 image-mask pairs
#      23 for i in range(5):
# ---> 24     visualize_image_and_mask(image_paths[i], mask_paths[i])
#
# <ipython-input-8-e20601715980> in visualize_image_and_mask(image_path, mask_path)
#       3
#       4 def visualize_image_and_mask(image_path, mask_path):
# ----> 5     image = cv2.imread(image_path)
#       6     image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
#       7
#
# TypeError: Can't convert object to 'str' for 'filename'
