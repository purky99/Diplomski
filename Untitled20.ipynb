# %% [markdown]
# <a href="https://colab.research.google.com/github/purky99/Diplomski/blob/main/Untitled20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow==2.10.0
# !pip install keras==2.10.0
# !pip install segmentation-models

# %%
from google.colab import drive
drive.mount('/content/drive')
# !unzip /content/drive/My\ Drive/data.zip -d /content/
dataset_path = '/content/data'

# %%
# !cat /proc/meminfo | grep 'MemAvailable' | awk '{print $2/1024/1024 " GB"}'
# Out:
# 23.7436 GB

# %%
import os
import cv2
import numpy as np
import segmentation_models as sm
import random
import glob
import keras
import re
import keras.backend as K
import matplotlib.pyplot as plt
from segmentation_models import Unet
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.layers import Input
from keras.models import Model
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from keras.wrappers.scikit_learn import KerasClassifier
# Out:
# Segmentation Models: using `keras` framework.

# %%
train_size = 0.6
val_size = 0.2
test_size = 0.2

data_dir = '/content/data_wo_shadows'
image_dir = os.path.join(data_dir, 'images_wo_gripper')
mask_dir = os.path.join(data_dir, 'segmentation_masks_wo_gripper')

# Get a list of all image filenames in the image_dir
all_image_filenames = os.listdir(image_dir)
selected_image_filenames = random.sample(all_image_filenames, 5000)

# create a list of mask filenames that correspond to the selected image filenames
selected_mask_paths = []
filtered_image_filenames = []
skipped_image_paths = []
for image_filename in selected_image_filenames:
    image_number = os.path.splitext(image_filename)[0]
    image_number = "".join(re.findall(r'\d+', image_number))
    mask_filename = image_number + '.png'
    mask_path = os.path.join(mask_dir, mask_filename)
    
    if os.path.exists(mask_path):
          selected_mask_paths.append(mask_path)
          filtered_image_filenames.append(image_filename)
    else:
        skipped_image_paths.append(os.path.join(image_dir, image_filename))
        

# create lists of image and mask paths for the selected images
selected_image_paths = [os.path.join(image_dir, f)
                        for f in filtered_image_filenames]

#keep green instance
def keep_green_instance(selected_mask_paths):
    mask = cv2.imread(selected_mask_paths, cv2.IMREAD_COLOR)
    lower_green = np.array([0, 100, 0])
    upper_green = np.array([100, 255, 100])
    green_mask = cv2.inRange(mask, lower_green, upper_green)
    return green_mask

image_dataset = []
mask_dataset = []
for img_path, mask_path in zip(selected_image_paths, selected_mask_paths):
    # load the image
    img = cv2.imread(img_path, cv2.IMREAD_COLOR)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)        

    # load the mask
    mask = keep_green_instance(mask_path)  
    
    image_dataset.append(img)
    mask_dataset.append(mask)

image_dataset = np.array(image_dataset)
mask_dataset = np.array(mask_dataset)

# expand dimensions for iamges and masks
mask_dataset = np.expand_dims(mask_dataset, axis=-1)


# image_dataset = image_dataset / 255.
# mask_dataset = mask_dataset / 255.

image_dataset = image_dataset.astype(np.float32) / 255.
mask_dataset = mask_dataset.astype(np.float32) / 255.


#x_train, x_val, y_train, y_val = train_test_split(image_dataset, mask_dataset, test_size=0.2, random_state=42)
# First, split the data into train and a temporary set (val + test)
x_train, temp_paths, y_train, temp_mask_paths = train_test_split(
    image_dataset, mask_dataset, train_size=train_size, random_state=42)

# Next, split the temporary set into validation and test sets
val_size_ratio = val_size / (val_size + test_size)
x_val, x_test, y_val, y_test = train_test_split(
    temp_paths, temp_mask_paths, test_size=1-val_size_ratio, random_state=42)

# %%
from keras.optimizers import Adam

# backbone
BACKBONE = 'resnet101'
preprocess_input = sm.get_preprocessing(BACKBONE)

# define model
base_model = sm.Unet(
    BACKBONE, 
    classes=1, 
    activation='sigmoid',
    encoder_weights='imagenet',
    encoder_freeze=True
)

# create model with preprocessing layers
input = Input(shape=(480, 480, 3), name='Input')
preprocessed = preprocess_input(input)
output = base_model(preprocessed)
# final model
model = Model(input, output, name='BaseModel')

model.compile(
    #'Adam',
    Adam(learning_rate=1e-5),
    #loss=sm.losses.bce_jaccard_loss,
    loss=sm.losses.dice_loss,
    #loss=sm.losses.binary_focal_loss,
    #loss='binary_crossentropy',
    metrics=[sm.metrics.iou_score],
)

early_stopping_callback = EarlyStopping(
    monitor='val_loss', patience=5, verbose=1)

checkpoint_callback = ModelCheckpoint(
    filepath='best_model_weights.h5',
    monitor='val_loss',
    save_weights_only=True,
    save_best_only=True,
    verbose=1
)
# Out:
# Downloading data from https://github.com/qubvel/classification_models/releases/download/0.0.1/resnet101_imagenet_1000_no_top.h5
# 171164896/171164896 [==============================] - 10s 0us/step

# %%
# fit the model
history = model.fit(
    x=x_train,
    y=y_train,
    batch_size=8,
    epochs=100,  # Increase the number of epochs
    validation_data=(x_val, y_val),
    callbacks=[checkpoint_callback, early_stopping_callback]
)
# Out:
# Epoch 1/100
# 375/375 [==============================] - ETA: 0s - loss: 0.9060 - iou_score: 0.0524
# Epoch 1: val_loss improved from inf to 0.95502, saving model to best_model_weights.h5
# 375/375 [==============================] - 82s 165ms/step - loss: 0.9060 - iou_score: 0.0524 - val_loss: 0.9550 - val_iou_score: 0.0239
# Epoch 2/100
# 375/375 [==============================] - ETA: 0s - loss: 0.8537 - iou_score: 0.0867
# Epoch 2: val_loss improved from 0.95502 to 0.91873, saving model to best_model_weights.h5
# 375/375 [==============================] - 56s 150ms/step - loss: 0.8537 - iou_score: 0.0867 - val_loss: 0.9187 - val_iou_score: 0.0450
# Epoch 3/100
# 375/375 [==============================] - ETA: 0s - loss: 0.8253 - iou_score: 0.1074
# Epoch 3: val_loss improved from 0.91873 to 0.85454, saving model to best_model_weights.h5
# 375/375 [==============================] - 56s 149ms/step - loss: 0.8253 - iou_score: 0.1074 - val_loss: 0.8545 - val_iou_score: 0.0837
# Epoch 4/100
# 375/375 [==============================] - ETA: 0s - loss: 0.7977 - iou_score: 0.1273
# Epoch 4: val_loss improved from 0.85454 to 0.76399, saving model to best_model_weights.h5
# 375/375 [==============================] - 56s 150ms/step - loss: 0.7977 - iou_score: 0.1273 - val_loss: 0.7640 - val_iou_score: 0.1547
# Epoch 5/100
# 375/375 [==============================] - ETA: 0s - loss: 0.7689 - iou_score: 0.1489
# Epoch 5: val_loss improved from 0.76399 to 0.73906, saving model to best_model_weights.h5
# 375/375 [==============================] - 56s 150ms/step - loss: 0.7689 - iou_score: 0.1489 - val_loss: 0.7391 - val_iou_score: 0.1742
# Epoch 6/100
# 375/375 [==============================] - ETA: 0s - loss: 0.7343 - iou_score: 0.1748
# Epoch 6: val_loss improved from 0.73906 to 0.70860, saving model to best_model_weights.h5
# 375/375 [==============================] - 56s 150ms/step - loss: 0.7343 - iou_score: 0.1748 - val_loss: 0.7086 - val_iou_score: 0.1986
# Epoch 7/100
# 375/375 [==============================] - ETA: 0s - loss: 0.6963 - iou_score: 0.2049
# Epoch 7: val_loss improved from 0.70860 to 0.67754, saving model to best_model_weights.h5
# 375/375 [==============================] - 56s 150ms/step - loss: 0.6963 - iou_score: 0.2049 - val_loss: 0.6775 - val_iou_score: 0.2240
# Epoch 8/100
# 375/375 [==============================] - ETA: 0s - loss: 0.6603 - iou_score: 0.2337
# Epoch 8: val_loss improved from 0.67754 to 0.64600, saving model to best_model_weights.h5
# 375/375 [==============================] - 56s 149ms/step - loss: 0.6603 - iou_score: 0.2337 - val_loss: 0.6460 - val_iou_score: 0.2501
# Epoch 9/100
# 375/375 [==============================] - ETA: 0s - loss: 0.6343 - iou_score: 0.2567
# Epoch 9: val_loss improved from 0.64600 to 0.60930, saving model to best_model_weights.h5
# 375/375 [==============================] - 56s 149ms/step - loss: 0.6343 - iou_score: 0.2567 - val_loss: 0.6093 - val_iou_score: 0.2812
# Epoch 10/100
# 375/375 [==============================] - ETA: 0s - loss: 0.5824 - iou_score: 0.2997
# Epoch 10: val_loss improved from 0.60930 to 0.57418, saving model to best_model_weights.h5
# 375/375 [==============================] - 56s 149ms/step - loss: 0.5824 - iou_score: 0.2997 - val_loss: 0.5742 - val_iou_score: 0.3116
# Epoch 11/100
# 375/375 [==============================] - ETA: 0s - loss: 0.5481 - iou_score: 0.3338
# Epoch 11: val_loss improved from 0.57418 to 0.53312, saving model to best_model_weights.h5
# 375/375 [==============================] - 56s 149ms/step - loss: 0.5481 - iou_score: 0.3338 - val_loss: 0.5331 - val_iou_score: 0.3481
# Epoch 12/100
# 375/375 [==============================] - ETA: 0s - loss: 0.5123 - iou_score: 0.3653
# Epoch 12: val_loss improved from 0.53312 to 0.49752, saving model to best_model_weights.h5
# 375/375 [==============================] - 56s 149ms/step - loss: 0.5123 - iou_score: 0.3653 - val_loss: 0.4975 - val_iou_score: 0.3795
# Epoch 13/100
# 375/375 [==============================] - ETA: 0s - loss: 0.4711 - iou_score: 0.4017
# Epoch 13: val_loss improved from 0.49752 to 0.45646, saving model to best_model_weights.h5
# 375/375 [==============================] - 56s 149ms/step - loss: 0.4711 - iou_score: 0.4017 - val_loss: 0.4565 - val_iou_score: 0.4178
# Epoch 14/100
# 375/375 [==============================] - ETA: 0s - loss: 0.4312 - iou_score: 0.4421
# Epoch 14: val_loss improved from 0.45646 to 0.41400, saving model to best_model_weights.h5
# 375/375 [==============================] - 56s 149ms/step - loss: 0.4312 - iou_score: 0.4421 - val_loss: 0.4140 - val_iou_score: 0.4621
# Epoch 15/100
# 375/375 [==============================] - ETA: 0s - loss: 0.4058 - iou_score: 0.4692
# Epoch 15: val_loss improved from 0.41400 to 0.39202, saving model to best_model_weights.h5
# 375/375 [==============================] - 56s 149ms/step - loss: 0.4058 - iou_score: 0.4692 - val_loss: 0.3920 - val_iou_score: 0.4780
# Epoch 16/100
# 375/375 [==============================] - ETA: 0s - loss: 0.3584 - iou_score: 0.5151
# Epoch 16: val_loss improved from 0.39202 to 0.35070, saving model to best_model_weights.h5
# 375/375 [==============================] - 56s 149ms/step - loss: 0.3584 - iou_score: 0.5151 - val_loss: 0.3507 - val_iou_score: 0.5213
# Epoch 17/100
# 375/375 [==============================] - ETA: 0s - loss: 0.3261 - iou_score: 0.5522
# Epoch 17: val_loss improved from 0.35070 to 0.32644, saving model to best_model_weights.h5
# 375/375 [==============================] - 56s 149ms/step - loss: 0.3261 - iou_score: 0.5522 - val_loss: 0.3264 - val_iou_score: 0.5467
# Epoch 18/100
# 375/375 [==============================] - ETA: 0s - loss: 0.2992 - iou_score: 0.5806
# Epoch 18: val_loss improved from 0.32644 to 0.28657, saving model to best_model_weights.h5
# 375/375 [==============================] - 56s 149ms/step - loss: 0.2992 - iou_score: 0.5806 - val_loss: 0.2866 - val_iou_score: 0.5942
# Epoch 19/100
# 375/375 [==============================] - ETA: 0s - loss: 0.2706 - iou_score: 0.6152
# Epoch 19: val_loss improved from 0.28657 to 0.26807, saving model to best_model_weights.h5
# 375/375 [==============================] - 56s 149ms/step - loss: 0.2706 - iou_score: 0.6152 - val_loss: 0.2681 - val_iou_score: 0.6163
# Epoch 20/100
# 375/375 [==============================] - ETA: 0s - loss: 0.2513 - iou_score: 0.6403
# Epoch 20: val_loss improved from 0.26807 to 0.23641, saving model to best_model_weights.h5
# 375/375 [==============================] - 56s 150ms/step - loss: 0.2513 - iou_score: 0.6403 - val_loss: 0.2364 - val_iou_score: 0.6546
# Epoch 21/100
# 375/375 [==============================] - ETA: 0s - loss: 0.2168 - iou_score: 0.6763
# Epoch 21: val_loss improved from 0.23641 to 0.22112, saving model to best_model_weights.h5
# 375/375 [==============================] - 56s 149ms/step - loss: 0.2168 - iou_score: 0.6763 - val_loss: 0.2211 - val_iou_score: 0.6735
# Epoch 22/100
# 375/375 [==============================] - ETA: 0s - loss: 0.1982 - iou_score: 0.7013
# Epoch 22: val_loss improved from 0.22112 to 0.20596, saving model to best_model_weights.h5
# 375/375 [==============================] - 56s 149ms/step - loss: 0.1982 - iou_score: 0.7013 - val_loss: 0.2060 - val_iou_score: 0.6908
# Epoch 23/100
# 375/375 [==============================] - ETA: 0s - loss: 0.1893 - iou_score: 0.7147
# Epoch 23: val_loss improved from 0.20596 to 0.18316, saving model to best_model_weights.h5
# 375/375 [==============================] - 56s 150ms/step - loss: 0.1893 - iou_score: 0.7147 - val_loss: 0.1832 - val_iou_score: 0.7230
# Epoch 24/100
# 375/375 [==============================] - ETA: 0s - loss: 0.1686 - iou_score: 0.7408
# Epoch 24: val_loss improved from 0.18316 to 0.16926, saving model to best_model_weights.h5
# 375/375 [==============================] - 56s 149ms/step - loss: 0.1686 - iou_score: 0.7408 - val_loss: 0.1693 - val_iou_score: 0.7400
# Epoch 25/100
# 375/375 [==============================] - ETA: 0s - loss: 0.1528 - iou_score: 0.7618
# Epoch 25: val_loss improved from 0.16926 to 0.16191, saving model to best_model_weights.h5
# 375/375 [==============================] - 56s 150ms/step - loss: 0.1528 - iou_score: 0.7618 - val_loss: 0.1619 - val_iou_score: 0.7480
# Epoch 26/100
# 375/375 [==============================] - ETA: 0s - loss: 0.1364 - iou_score: 0.7830
# Epoch 26: val_loss improved from 0.16191 to 0.14435, saving model to best_model_weights.h5
# 375/375 [==============================] - 56s 150ms/step - loss: 0.1364 - iou_score: 0.7830 - val_loss: 0.1443 - val_iou_score: 0.7744
# Epoch 27/100
# 375/375 [==============================] - ETA: 0s - loss: 0.1318 - iou_score: 0.7935
# Epoch 27: val_loss improved from 0.14435 to 0.13461, saving model to best_model_weights.h5
# 375/375 [==============================] - 56s 149ms/step - loss: 0.1318 - iou_score: 0.7935 - val_loss: 0.1346 - val_iou_score: 0.7873
# Epoch 28/100
# 375/375 [==============================] - ETA: 0s - loss: 0.1215 - iou_score: 0.8066
# Epoch 28: val_loss improved from 0.13461 to 0.12841, saving model to best_model_weights.h5
# 375/375 [==============================] - 56s 149ms/step - loss: 0.1215 - iou_score: 0.8066 - val_loss: 0.1284 - val_iou_score: 0.7958
# Epoch 29/100
# 375/375 [==============================] - ETA: 0s - loss: 0.1087 - iou_score: 0.8246
# Epoch 29: val_loss improved from 0.12841 to 0.12166, saving model to best_model_weights.h5
# 375/375 [==============================] - 56s 149ms/step - loss: 0.1087 - iou_score: 0.8246 - val_loss: 0.1217 - val_iou_score: 0.8072
# Epoch 30/100
# 375/375 [==============================] - ETA: 0s - loss: 0.1098 - iou_score: 0.8250
# Epoch 30: val_loss improved from 0.12166 to 0.11268, saving model to best_model_weights.h5
# 375/375 [==============================] - 56s 150ms/step - loss: 0.1098 - iou_score: 0.8250 - val_loss: 0.1127 - val_iou_score: 0.8204
# Epoch 31/100
# 375/375 [==============================] - ETA: 0s - loss: 0.1072 - iou_score: 0.8313
# Epoch 31: val_loss improved from 0.11268 to 0.10952, saving model to best_model_weights.h5
# 375/375 [==============================] - 56s 149ms/step - loss: 0.1072 - iou_score: 0.8313 - val_loss: 0.1095 - val_iou_score: 0.8247
# Epoch 32/100
# 375/375 [==============================] - ETA: 0s - loss: 0.1042 - iou_score: 0.8364
# Epoch 32: val_loss did not improve from 0.10952
# 375/375 [==============================] - 55s 147ms/step - loss: 0.1042 - iou_score: 0.8364 - val_loss: 0.1188 - val_iou_score: 0.8104
# Epoch 33/100
# 375/375 [==============================] - ETA: 0s - loss: 0.0899 - iou_score: 0.8526
# Epoch 33: val_loss improved from 0.10952 to 0.10440, saving model to best_model_weights.h5
# 375/375 [==============================] - 56s 150ms/step - loss: 0.0899 - iou_score: 0.8526 - val_loss: 0.1044 - val_iou_score: 0.8330
# Epoch 34/100
# 375/375 [==============================] - ETA: 0s - loss: 0.0825 - iou_score: 0.8631
# Epoch 34: val_loss improved from 0.10440 to 0.09603, saving model to best_model_weights.h5
# 375/375 [==============================] - 56s 150ms/step - loss: 0.0825 - iou_score: 0.8631 - val_loss: 0.0960 - val_iou_score: 0.8463
# Epoch 35/100
# 375/375 [==============================] - ETA: 0s - loss: 0.0863 - iou_score: 0.8633
# Epoch 35: val_loss improved from 0.09603 to 0.08765, saving model to best_model_weights.h5
# 375/375 [==============================] - 56s 150ms/step - loss: 0.0863 - iou_score: 0.8633 - val_loss: 0.0877 - val_iou_score: 0.8594
# Epoch 36/100
# 375/375 [==============================] - ETA: 0s - loss: 0.0961 - iou_score: 0.8546
# Epoch 36: val_loss did not improve from 0.08765
# 375/375 [==============================] - 55s 148ms/step - loss: 0.0961 - iou_score: 0.8546 - val_loss: 0.0902 - val_iou_score: 0.8552
# Epoch 37/100
# 375/375 [==============================] - ETA: 0s - loss: 0.0738 - iou_score: 0.8791
# Epoch 37: val_loss did not improve from 0.08765
# 375/375 [==============================] - 55s 148ms/step - loss: 0.0738 - iou_score: 0.8791 - val_loss: 0.0991 - val_iou_score: 0.8399
# Epoch 38/100
# 375/375 [==============================] - ETA: 0s - loss: 0.0888 - iou_score: 0.8672
# Epoch 38: val_loss improved from 0.08765 to 0.08092, saving model to best_model_weights.h5
# 375/375 [==============================] - 56s 150ms/step - loss: 0.0888 - iou_score: 0.8672 - val_loss: 0.0809 - val_iou_score: 0.8697
# Epoch 39/100
# 375/375 [==============================] - ETA: 0s - loss: 0.0810 - iou_score: 0.8750
# Epoch 39: val_loss did not improve from 0.08092
# 375/375 [==============================] - 55s 147ms/step - loss: 0.0810 - iou_score: 0.8750 - val_loss: 0.0831 - val_iou_score: 0.8677
# Epoch 40/100
# 375/375 [==============================] - ETA: 0s - loss: 0.0596 - iou_score: 0.8988
# Epoch 40: val_loss improved from 0.08092 to 0.07811, saving model to best_model_weights.h5
# 375/375 [==============================] - 56s 149ms/step - loss: 0.0596 - iou_score: 0.8988 - val_loss: 0.0781 - val_iou_score: 0.8755
# Epoch 41/100
# 375/375 [==============================] - ETA: 0s - loss: 0.0700 - iou_score: 0.8894
# Epoch 41: val_loss improved from 0.07811 to 0.07366, saving model to best_model_weights.h5
# 375/375 [==============================] - 56s 150ms/step - loss: 0.0700 - iou_score: 0.8894 - val_loss: 0.0737 - val_iou_score: 0.8818
# Epoch 42/100
# 375/375 [==============================] - ETA: 0s - loss: 0.0566 - iou_score: 0.9043
# Epoch 42: val_loss improved from 0.07366 to 0.07128, saving model to best_model_weights.h5
# 375/375 [==============================] - 56s 150ms/step - loss: 0.0566 - iou_score: 0.9043 - val_loss: 0.0713 - val_iou_score: 0.8854
# Epoch 43/100
# 375/375 [==============================] - ETA: 0s - loss: 0.0619 - iou_score: 0.9010
# Epoch 43: val_loss improved from 0.07128 to 0.07006, saving model to best_model_weights.h5
# 375/375 [==============================] - 56s 149ms/step - loss: 0.0619 - iou_score: 0.9010 - val_loss: 0.0701 - val_iou_score: 0.8883
# Epoch 44/100
# 375/375 [==============================] - ETA: 0s - loss: 0.0680 - iou_score: 0.8946
# Epoch 44: val_loss did not improve from 0.07006
# 375/375 [==============================] - 55s 148ms/step - loss: 0.0680 - iou_score: 0.8946 - val_loss: 0.0748 - val_iou_score: 0.8803
# Epoch 45/100
# 375/375 [==============================] - ETA: 0s - loss: 0.0573 - iou_score: 0.9056
# Epoch 45: val_loss improved from 0.07006 to 0.06676, saving model to best_model_weights.h5
# 375/375 [==============================] - 56s 150ms/step - loss: 0.0573 - iou_score: 0.9056 - val_loss: 0.0668 - val_iou_score: 0.8939
# Epoch 46/100
# 375/375 [==============================] - ETA: 0s - loss: 0.0601 - iou_score: 0.9056
# Epoch 46: val_loss did not improve from 0.06676
# 375/375 [==============================] - 55s 148ms/step - loss: 0.0601 - iou_score: 0.9056 - val_loss: 0.0692 - val_iou_score: 0.8885
# Epoch 47/100
# 375/375 [==============================] - ETA: 0s - loss: 0.0636 - iou_score: 0.9024
# Epoch 47: val_loss did not improve from 0.06676
# 375/375 [==============================] - 55s 148ms/step - loss: 0.0636 - iou_score: 0.9024 - val_loss: 0.0702 - val_iou_score: 0.8867
# Epoch 48/100
# 375/375 [==============================] - ETA: 0s - loss: 0.0525 - iou_score: 0.9149
# Epoch 48: val_loss did not improve from 0.06676
# 375/375 [==============================] - 55s 148ms/step - loss: 0.0525 - iou_score: 0.9149 - val_loss: 0.0672 - val_iou_score: 0.8916
# Epoch 49/100
# 375/375 [==============================] - ETA: 0s - loss: 0.0597 - iou_score: 0.9088
# Epoch 49: val_loss improved from 0.06676 to 0.06400, saving model to best_model_weights.h5
# 375/375 [==============================] - 56s 150ms/step - loss: 0.0597 - iou_score: 0.9088 - val_loss: 0.0640 - val_iou_score: 0.8976
# Epoch 50/100
# 375/375 [==============================] - ETA: 0s - loss: 0.0525 - iou_score: 0.9149
# Epoch 50: val_loss did not improve from 0.06400
# 375/375 [==============================] - 55s 148ms/step - loss: 0.0525 - iou_score: 0.9149 - val_loss: 0.0795 - val_iou_score: 0.8722
# Epoch 51/100
# 375/375 [==============================] - ETA: 0s - loss: 0.0594 - iou_score: 0.9074
# Epoch 51: val_loss improved from 0.06400 to 0.06268, saving model to best_model_weights.h5
# 375/375 [==============================] - 56s 150ms/step - loss: 0.0594 - iou_score: 0.9074 - val_loss: 0.0627 - val_iou_score: 0.8990
# Epoch 52/100
# 375/375 [==============================] - ETA: 0s - loss: 0.0478 - iou_score: 0.9211
# Epoch 52: val_loss improved from 0.06268 to 0.05993, saving model to best_model_weights.h5
# 375/375 [==============================] - 56s 150ms/step - loss: 0.0478 - iou_score: 0.9211 - val_loss: 0.0599 - val_iou_score: 0.9036
# Epoch 53/100
# 375/375 [==============================] - ETA: 0s - loss: 0.0596 - iou_score: 0.9107
# Epoch 53: val_loss did not improve from 0.05993
# 375/375 [==============================] - 55s 148ms/step - loss: 0.0596 - iou_score: 0.9107 - val_loss: 0.0648 - val_iou_score: 0.8949
# Epoch 54/100
# 375/375 [==============================] - ETA: 0s - loss: 0.0427 - iou_score: 0.9263
# Epoch 54: val_loss did not improve from 0.05993
# 375/375 [==============================] - 55s 148ms/step - loss: 0.0427 - iou_score: 0.9263 - val_loss: 0.0626 - val_iou_score: 0.8996
# Epoch 55/100
# 375/375 [==============================] - ETA: 0s - loss: 0.0699 - iou_score: 0.8993
# Epoch 55: val_loss did not improve from 0.05993
# 375/375 [==============================] - 55s 148ms/step - loss: 0.0699 - iou_score: 0.8993 - val_loss: 0.0610 - val_iou_score: 0.9018
# Epoch 56/100
# 375/375 [==============================] - ETA: 0s - loss: 0.0575 - iou_score: 0.9131
# Epoch 56: val_loss did not improve from 0.05993
# 375/375 [==============================] - 55s 148ms/step - loss: 0.0575 - iou_score: 0.9131 - val_loss: 0.0633 - val_iou_score: 0.8973
# Epoch 57/100
# 375/375 [==============================] - ETA: 0s - loss: 0.0712 - iou_score: 0.8987
# Epoch 57: val_loss improved from 0.05993 to 0.05613, saving model to best_model_weights.h5
# 375/375 [==============================] - 56s 150ms/step - loss: 0.0712 - iou_score: 0.8987 - val_loss: 0.0561 - val_iou_score: 0.9095
# Epoch 58/100
# 375/375 [==============================] - ETA: 0s - loss: 0.0625 - iou_score: 0.9088
# Epoch 58: val_loss did not improve from 0.05613
# 375/375 [==============================] - 55s 148ms/step - loss: 0.0625 - iou_score: 0.9088 - val_loss: 0.0580 - val_iou_score: 0.9082
# Epoch 59/100
# 375/375 [==============================] - ETA: 0s - loss: 0.0524 - iou_score: 0.9196
# Epoch 59: val_loss did not improve from 0.05613
# 375/375 [==============================] - 55s 148ms/step - loss: 0.0524 - iou_score: 0.9196 - val_loss: 0.0563 - val_iou_score: 0.9104
# Epoch 60/100
# 375/375 [==============================] - ETA: 0s - loss: 0.0601 - iou_score: 0.9118
# Epoch 60: val_loss did not improve from 0.05613
# 375/375 [==============================] - 55s 148ms/step - loss: 0.0601 - iou_score: 0.9118 - val_loss: 0.1125 - val_iou_score: 0.8221
# Epoch 61/100
# 375/375 [==============================] - ETA: 0s - loss: 0.0493 - iou_score: 0.9216
# Epoch 61: val_loss did not improve from 0.05613
# 375/375 [==============================] - 55s 148ms/step - loss: 0.0493 - iou_score: 0.9216 - val_loss: 0.0576 - val_iou_score: 0.9064
# Epoch 62/100
# 375/375 [==============================] - ETA: 0s - loss: 0.0616 - iou_score: 0.9103
# Epoch 62: val_loss improved from 0.05613 to 0.05444, saving model to best_model_weights.h5
# 375/375 [==============================] - 56s 149ms/step - loss: 0.0616 - iou_score: 0.9103 - val_loss: 0.0544 - val_iou_score: 0.9121
# Epoch 63/100
# 375/375 [==============================] - ETA: 0s - loss: 0.0491 - iou_score: 0.9253
# Epoch 63: val_loss did not improve from 0.05444
# 375/375 [==============================] - 55s 148ms/step - loss: 0.0491 - iou_score: 0.9253 - val_loss: 0.0580 - val_iou_score: 0.9057
# Epoch 64/100
# 375/375 [==============================] - ETA: 0s - loss: 0.0470 - iou_score: 0.9248
# Epoch 64: val_loss did not improve from 0.05444
# 375/375 [==============================] - 55s 148ms/step - loss: 0.0470 - iou_score: 0.9248 - val_loss: 0.0549 - val_iou_score: 0.9123
# Epoch 65/100
# 375/375 [==============================] - ETA: 0s - loss: 0.0542 - iou_score: 0.9186
# Epoch 65: val_loss did not improve from 0.05444
# 375/375 [==============================] - 55s 148ms/step - loss: 0.0542 - iou_score: 0.9186 - val_loss: 0.0546 - val_iou_score: 0.9128
# Epoch 66/100
# 375/375 [==============================] - ETA: 0s - loss: 0.0526 - iou_score: 0.9214
# Epoch 66: val_loss did not improve from 0.05444
# 375/375 [==============================] - 55s 148ms/step - loss: 0.0526 - iou_score: 0.9214 - val_loss: 0.0555 - val_iou_score: 0.9116
# Epoch 67/100
# 375/375 [==============================] - ETA: 0s - loss: 0.0426 - iou_score: 0.9301
# Epoch 67: val_loss did not improve from 0.05444
# 375/375 [==============================] - 55s 147ms/step - loss: 0.0426 - iou_score: 0.9301 - val_loss: 0.0594 - val_iou_score: 0.9037
# Epoch 67: early stopping

# %%
import torch
import gc

# Clear GPU memory cache
torch.cuda.empty_cache()

# Clear unreferenced objects from CPU memory
gc.collect()
# Out:
# 0

# %%
model.save_weights('final_model_weights.h5')

# %%
import os

folder_path = '/content/gdrive/My Drive/training_weights2'
if not os.path.exists(folder_path):
    os.makedirs(folder_path)

# %%
model.save_weights('/content/gdrive/My Drive/training_weights2/final_model_weights.h5')

# %%
# Create the plots folder in your Google Drive if it doesn't exist
import os
plots_dir = '/content/drive/MyDrive/plots2'
if not os.path.exists(plots_dir):
    os.makedirs(plots_dir)

# Plot training & validation IoU scores
plt.figure(figsize=(12, 6))
plt.plot(history.history['iou_score'], label='Training IoU Score')
plt.plot(history.history['val_iou_score'], label='Validation IoU Score')
plt.title('Model IoU Score')
plt.ylabel('IoU Score')
plt.xlabel('Epoch')
plt.legend(loc='upper left')
plt.savefig(os.path.join(plots_dir, 'Model_IoU_Score.png'))
plt.show()

# Plot training & validation loss values
plt.figure(figsize=(12, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='upper right')
plt.savefig(os.path.join(plots_dir, 'Model_Loss.png'))
plt.show()

# %%
# Load the saved model weights
model.load_weights('best_model_weights.h5')

# Make predictions using the model for each test image
predictions = model.predict(x_test)

# Post-process the predicted masks (optional)
predicted_masks = (predictions > 0.5).astype(np.uint8)

# Save the predicted masks as images (optional)
output_dir = '/content/predicted_masks2'
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

for i, predicted_mask in enumerate(predicted_masks):
    mask = predicted_mask[..., 0] * 255  # Scale the mask back to [0, 255]
    output_mask_path = os.path.join(output_dir, f'mask_{i}.png')
    cv2.imwrite(output_mask_path, mask)
# Out:
# 32/32 [==============================] - 6s 117ms/step
